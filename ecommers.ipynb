# %%
import pandas as pd

# %%
df=pd.read_csv("C:/project/ecommerce_data.csv")
print(df)
# Out:
#         Order_ID  Order_Date  Customer_Name       City     Product  \
# 0      ORD116809  2024-02-07    Pooja Patel    Gurgaon     Monitor
# 1      ORD116171  2024-02-11   Vikas Sharma    Gurgaon  Headphones
# 2      ORD123118  2023-06-07  Nikhil Sharma    Gurgaon      Laptop
# 3      ORD123757  2024-11-16   Nikhil Patel    Lucknow      Laptop
# 4      ORD101588  2023-11-24    Aarav Singh  Hyderabad       Mouse
# ...          ...         ...            ...        ...         ...
# 30245  ORD129802  2025-06-25   Simran Patel      Ajmer         SSD
# 30246  ORD105390  2023-03-16    Kavya Mehta      Ajmer      Camera
# 30247  ORD100860  2025-02-23    Rahul Patel      Surat      Router
# 30248  ORD115795  2023-05-07    Aditi Patel     Mumbai      Webcam
# 30249  ORD123654  2024-08-12    Rohan Gupta     Jaipur     Earbuds
#
#           Category  Quantity  Unit_Price  Discount      Sales Payment_Mode  \
# 0           Gaming       5.0    22061.08      0.05  104790.13  Net Banking
# ...

# %%
df.head(5)
# Out:
#     Order_ID  Order_Date  Customer_Name       City     Product     Category  \
# 0  ORD116809  2024-02-07    Pooja Patel    Gurgaon     Monitor       Gaming
# 1  ORD116171  2024-02-11   Vikas Sharma    Gurgaon  Headphones  Accessories
# 2  ORD123118  2023-06-07  Nikhil Sharma    Gurgaon      Laptop       Gaming
# 3  ORD123757  2024-11-16   Nikhil Patel    Lucknow      Laptop    Computers
# 4  ORD101588  2023-11-24    Aarav Singh  Hyderabad       Mouse  Electronics
#
#    Quantity  Unit_Price  Discount      Sales Payment_Mode Order_Status  \
# 0       5.0    22061.08      0.05  104790.13  Net Banking    Delivered
# 1       4.0         NaN      0.30  305141.62  Net Banking      Pending
# 2       3.0    51216.27      0.20  122919.05   Debit Card     Returned
# 3       7.0    54651.12      0.05  363429.95  Credit Card    Cancelled
# 4       5.0    77021.50      0.00  385107.50          UPI    delivered
#
#    Customer_Age  Rating  Delivery_Days
# 0          25.0     3.0           12.0
# ...

# %%
df.tail(10)
# Out:
#         Order_ID  Order_Date Customer_Name      City     Product     Category  \
# 30240  ORD106265  2025-10-01  Nikhil Joshi    Mumbai     Monitor    Computers
# 30241  ORD122118  2025-07-09    Rohan Jain     Noida  Smartwatch       Gaming
# 30242  ORD111284  2023-07-15   Mohit Joshi     Sikar     Speaker    Computers
# 30243  ORD111964  2025-09-23   Rahul Mehta     Delhi      Webcam  Electronics
# 30244  ORD121575  2025-06-28   Sneha Singh  Udaipur       Webcam  Electronics
# 30245  ORD129802  2025-06-25  Simran Patel     Ajmer         SSD  Electronics
# 30246  ORD105390  2023-03-16   Kavya Mehta     Ajmer      Camera       Gaming
# 30247  ORD100860  2025-02-23   Rahul Patel     Surat      Router  Electronics
# 30248  ORD115795  2023-05-07   Aditi Patel    Mumbai      Webcam       Gaming
# 30249  ORD123654  2024-08-12   Rohan Gupta    Jaipur     Earbuds    Computers
#
#        Quantity  Unit_Price  Discount      Sales Payment_Mode Order_Status  \
# ...

# %%
print(df.shape)
# Out:
# (30250, 15)

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_Name', 'City', 'Product',
#        'Category', 'Quantity', 'Unit_Price', 'Discount', 'Sales',
#        'Payment_Mode', 'Order_Status', 'Customer_Age', 'Rating',
#        'Delivery_Days'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Order_ID          object
# Order_Date        object
# Customer_Name     object
# City              object
# Product           object
# Category          object
# Quantity         float64
# Unit_Price       float64
# Discount         float64
# Sales            float64
# Payment_Mode      object
# Order_Status      object
# Customer_Age     float64
# Rating           float64
# Delivery_Days    float64
# dtype: object

# %%
df.describe()
# Out:
#            Quantity     Unit_Price      Discount          Sales  Customer_Age  \
# count  30069.000000   30028.000000  29999.000000   29945.000000  29900.000000
# mean       4.186272   60239.819300      0.149475  204679.728622     43.716722
# std        4.748321   34602.871499      0.099881  169434.851700     15.311417
# min       -1.000000     301.110000      0.000000     210.780000      5.000000
# 25%        2.000000   30499.980000      0.050000   68711.690000     31.000000
# 50%        4.000000   60198.065000      0.150000  158741.350000     44.000000
# 75%        6.000000   90260.292500      0.250000  303939.200000     57.000000
# max      100.000000  119996.870000      0.300000  839697.250000    120.000000
#
#              Rating  Delivery_Days
# count  29797.000000   29947.000000
# mean       3.016344       7.616422
# std        1.437808       5.182616
# min        0.000000       0.000000
# 25%        2.000000       4.000000
# 50%        3.000000       7.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# Order_ID           0
# Order_Date       251
# Customer_Name    356
# City             304
# Product          252
# Category         203
# Quantity         181
# Unit_Price       222
# Discount         251
# Sales            305
# Payment_Mode     254
# Order_Status     200
# Customer_Age     350
# Rating           453
# Delivery_Days    303
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 250

# %%
print(df[df["Quantity"]>5])
# Out:
#         Order_ID  Order_Date  Customer_Name       City       Product  \
# 3      ORD123757  2024-11-16   Nikhil Patel    Lucknow        Laptop
# 9      ORD125221  2025-07-28   Simran Mehta      Delhi     USB Cable
# 12     ORD104672  2024-01-07   Simran Verma  Ahmedabad         Mouse
# 13     ORD110016  2023-10-25  Kavya Agarwal      Sikar        Webcam
# 16     ORD116196  2024-03-24    Anjali Jain      Noida  Mobile Phone
# ...          ...         ...            ...        ...           ...
# 30242  ORD111284  2023-07-15    Mohit Joshi      Sikar       Speaker
# 30243  ORD111964  2025-09-23    Rahul Mehta      Delhi        Webcam
# 30245  ORD129802  2025-06-25   Simran Patel      Ajmer           SSD
# 30246  ORD105390  2023-03-16    Kavya Mehta      Ajmer        Camera
# 30249  ORD123654  2024-08-12    Rohan Gupta     Jaipur       Earbuds
#
#           Category  Quantity  Unit_Price  Discount      Sales Payment_Mode  \
# ...

# %%
df= df[df["City"] == "Jaipur"]
print(df)
# Out:
#         Order_ID  Order_Date  Customer_Name    City       Product  \
# 7      ORD110959  2024-08-23    Simran Jain  Jaipur    Smartwatch
# 20     ORD105284  2023-09-23    Kavya Mehta  Jaipur     Hard Disk
# 57     ORD127876  2023-04-07    Aarav Verma  Jaipur        Camera
# 98     ORD106909  2024-03-17  Karan Agarwal  Jaipur  Gaming Chair
# 122    ORD100622  2023-01-21    Rahul Gupta  Jaipur     USB Cable
# ...          ...         ...            ...     ...           ...
# 30160  ORD113417  2023-07-18     Neha Gupta  Jaipur         Mouse
# 30166  ORD103943  2024-03-07   Anjali Verma  Jaipur  Gaming Chair
# 30184  ORD111016  2025-03-05    Amit Sharma  Jaipur     USB Cable
# 30221  ORD106420  2023-09-14    Sneha Singh  Jaipur    Smartwatch
# 30249  ORD123654  2024-08-12    Rohan Gupta  Jaipur       Earbuds
#
#           Category  Quantity  Unit_Price  Discount      Sales Payment_Mode  \
# 7      Electronics       2.0    87304.23      0.05  165878.04         Cash
# ...

# %%
df[df["Sales"]>50000]
# Out:
#         Order_ID  Order_Date  Customer_Name    City       Product  \
# 7      ORD110959  2024-08-23    Simran Jain  Jaipur    Smartwatch
# 20     ORD105284  2023-09-23    Kavya Mehta  Jaipur     Hard Disk
# 57     ORD127876  2023-04-07    Aarav Verma  Jaipur        Camera
# 98     ORD106909  2024-03-17  Karan Agarwal  Jaipur  Gaming Chair
# 122    ORD100622  2023-01-21    Rahul Gupta  Jaipur     USB Cable
# ...          ...         ...            ...     ...           ...
# 30086  ORD114948  2023-09-16     Sneha Jain  Jaipur  Gaming Chair
# 30109  ORD129090  2024-02-18     Kavya Khan  Jaipur    Smartwatch
# 30145  ORD128374  2025-01-19     Sneha Jain  Jaipur       Speaker
# 30221  ORD106420  2023-09-14    Sneha Singh  Jaipur    Smartwatch
# 30249  ORD123654  2024-08-12    Rohan Gupta  Jaipur       Earbuds
#
#           Category  Quantity  Unit_Price  Discount      Sales Payment_Mode  \
# 7      Electronics       2.0    87304.23      0.05  165878.04         Cash
# ...

# %%
df[df["Order_Status"] == "Delivered"]
# Out:
#         Order_ID  Order_Date  Customer_Name    City     Product     Category  \
# 7      ORD110959  2024-08-23    Simran Jain  Jaipur  Smartwatch  Electronics
# 158    ORD108504  2025-12-11     Amit Patel  Jaipur     Earbuds  Electronics
# 287    ORD105225  2025-07-18     Rahul Khan  Jaipur     Earbuds  Electronics
# 305    ORD124539  2024-01-13    Priya Gupta  Jaipur    Keyboard       Mobile
# 310    ORD119432  04/01/2025     Pooja Khan  Jaipur         SSD  Accessories
# ...          ...         ...            ...     ...         ...          ...
# 29580  ORD126144  2025-07-14     Neha Patel  Jaipur      Router       Gaming
# 29656  ORD107805  2023-01-22    Kavya Mehta  Jaipur   USB Cable  Accessories
# 29665  ORD123944  2023-09-16  Nikhil Sharma  Jaipur        Desk    Computers
# 29905  ORD129945  2023-10-19     Neha Joshi  Jaipur      Laptop  Electronics
# 29974  ORD105855  2025-12-29    Aarav Gupta  Jaipur      Camera       Gaming
#
# ...

# %%
df["City"].nunique()
# Out:
# 1

# %%
print("Unique Cities:" , df["City"].nunique())
# Out:
# Unique Cities: 1

# %%
print("Payment Modes:", df["Payment_Mode"].unique())
# Out:
# Payment Modes: ['Cash' 'Wallet' 'UPI' 'Credit Card' 'Debit Card' 'Net Banking'
#  'debit card' nan 'upi' 'Credit card']

# %%
print("Average Sales:" , df["Sales"].mean())
# Out:
# Average Sales: 210952.5750474799

# %%
# Questions

# %%
df.groupby("City")["Sales"].sum()
# Out:
# City
# Jaipur    2.887941e+08
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Sales"].mean()
# Out:
# Category
# Accessories    200216.388939
# Computers      199666.136948
# Electronics    215814.716742
# Gaming         197733.376283
# Mobile         238543.769885
# accessories    396445.264000
# computers      146881.560000
# electronics    163410.520000
# gaming         447550.430000
# mobile         182109.502000
# Name: Sales, dtype: float64

# %%
df.groupby("Product")["Quantity"].sum()
# Out:
# Product
# Camera          406.0
# Desk            222.0
# Earbuds         243.0
# Gaming Chair    314.0
# Hard Disk       265.0
# Headphones      277.0
# Keyboard        225.0
# Laptop          389.0
# Mobile Phone    268.0
# Monitor         330.0
# Mouse           249.0
# Power Bank      311.0
# Printer         249.0
# Router          199.0
# SSD             255.0
# Smartwatch      259.0
# Speaker         392.0
# Tablet          302.0
# USB Cable       330.0
# Webcam          283.0
# camera            9.0
# desk             10.0
# hard disk         1.0
# laptop            9.0
# mobile phone      5.0
# monitor          13.0
# mouse             5.0
# power bank        6.0
# printer           3.0
# router           12.0
# smartwatch       16.0
# tablet           16.0
# usb cable         3.0
# Name: Quantity, dtype: float64

# %%
df.groupby("Payment_Mode").agg({
    "Sales":["sum","mean"],
    "Quantity":"sum"})
# Out:
#                     Sales                Quantity
#                       sum           mean      sum
# Payment_Mode
# Cash          42354363.01  187408.685885    869.0
# Credit Card   50901208.69  207760.035469   1000.0
# Credit card    1557036.72  311407.344000     25.0
# Debit Card    47327514.48  215125.065818    943.0
# Net Banking   54077836.74  239282.463451   1033.0
# UPI           43489990.74  200414.703871   1042.0
# Wallet        44998295.61  212256.111368    923.0
# debit card      804272.48  268090.826667     16.0
# upi             529625.51  264812.755000      9.0

# %%
df["Order_Status"].value_counts()
# Out:
# Order_Status
# Pending      288
# Returned     276
# Cancelled    267
# Shipped      262
# Delivered    257
# delivered      6
#  SHIPPED       5
# PENDING        4
# returned       4
# cancelled      1
# Name: count, dtype: int64

# %%
df["Payment_Mode"].value_counts()
# Out:
# Payment_Mode
# Credit Card    251
# Cash           228
# Net Banking    227
# Debit Card     224
# UPI            218
# Wallet         212
# Credit card      5
# debit card       3
# upi              2
# Name: count, dtype: int64

# %%
df["Product"].value_counts().head(10)
# Out:
# Product
# Camera          78
# Monitor         78
# Gaming Chair    75
# Tablet          75
# Webcam          74
# Speaker         73
# Power Bank      73
# Headphones      71
# Laptop          69
# Hard Disk       68
# Name: count, dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Jaipur    1383
# Name: count, dtype: int64

# %%
df.nlargest(10,"Sales")
# Out:
#         Order_ID  Order_Date  Customer_Name    City     Product     Category  \
# 29905  ORD129945  2023-10-19     Neha Joshi  Jaipur      Laptop  Electronics
# 29086  ORD116748  2023-10-11  Nikhil Sharma  Jaipur  Headphones  Accessories
# 25376  ORD129790  2025-05-03  Aarav Agarwal  Jaipur      Camera    Computers
# 15823  ORD122381  2023-10-28   Priya Sharma  Jaipur     Monitor       Mobile
# 9194   ORD122960  2024-02-18     Amit Mehta  Jaipur        Desk  Electronics
# 27468  ORD101316  2024-08-10    Pooja Gupta  Jaipur  Power Bank       Mobile
# 4693   ORD110563  2024-01-05   Karan Sharma  Jaipur     Printer  Electronics
# 12455  ORD104941  2025-09-11    Kavya Joshi  Jaipur      Camera       Mobile
# 5063   ORD115594  2024-01-01  Kavya Agarwal  Jaipur  Smartwatch       Gaming
# 24590  ORD120884  2024-01-11    Sneha Joshi  Jaipur     Speaker       Mobile
#
#        Quantity  Unit_Price  Discount      Sales Payment_Mode Order_Status  \
# ...

# %%
df.sort_values("Rating", ascending=False)
# Out:
#         Order_ID  Order_Date  Customer_Name    City       Product  \
# 12844  ORD127487  2025-04-01   Nikhil Mehta  Jaipur        Webcam
# 7432   ORD127640  2023-04-16   Nikhil Gupta  Jaipur  Gaming Chair
# 5910   ORD113610  2024-08-07   Rohan Sharma  Jaipur          Desk
# 25118  ORD122742  2025-05-31    Kavya Joshi  Jaipur        Router
# 15944  ORD124588  2024-10-21      Neha Khan  Jaipur        Router
# ...          ...         ...            ...     ...           ...
# 24736  ORD118949  2024-01-21  Rohan Agarwal  Jaipur    Headphones
# 24804  ORD125746  2023-07-15     Mohit Jain  Jaipur      Keyboard
# 24987  ORD114631  2023-04-10    Pooja Verma  Jaipur      Keyboard
# 25734  ORD100522  2023-02-25    Mohit Gupta  Jaipur        Camera
# 27980  ORD116500  2024-05-02     Vikas Jain  Jaipur    Headphones
#
#           Category  Quantity  Unit_Price  Discount      Sales Payment_Mode  \
# 12844       Mobile       2.0    67128.93      0.25  100693.39       Wallet
# ...

# %%
df.nlargest(10, "Delivery_Days")
# Out:
#        Order_ID  Order_Date  Customer_Name    City       Product     Category  \
# 7657  ORD127802  2024-05-27   Simran Joshi  Jaipur    Smartwatch    Computers
# 20    ORD105284  2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 592   ORD104186  2023-12-16     Rohan Jain  Jaipur       Printer       Gaming
# 684   ORD128185  2023-06-18    Simran Jain  Jaipur    Power Bank  Accessories
# 1192  ORD123376  2023-10-01    Aarav Singh  Jaipur     USB Cable       Gaming
# 1414  ORD101053  2023-02-13    Mohit Verma  Jaipur     USB Cable       Gaming
# 1466  ORD117542  2025-09-07     Aarav Jain  Jaipur        Camera  Electronics
# 1699  ORD116556  2024-08-12    Pooja Singh  Jaipur  Mobile Phone  Electronics
# 2017  ORD116273  2025-05-27  Pooja Agarwal  Jaipur        Tablet       Mobile
# 2391  ORD116219  2025-03-21    Simran Jain  Jaipur       Monitor       Mobile
#
#       Quantity  Unit_Price  Discount      Sales Payment_Mode Order_Status  \
# ...

# %%
df["Customer_Age"] = df["Customer_Age"].fillna(
    df["Customer_Age"].mean()
)

# %%
df["Customer_Age"]
# Out:
# 7        33.0
# 20       49.0
# 57       60.0
# 98       40.0
# 122      58.0
#          ...
# 30160    46.0
# 30166    18.0
# 30184    48.0
# 30221    31.0
# 30249    31.0
# Name: Customer_Age, Length: 1383, dtype: float64

# %%
df.head()
# Out:
#       Order_ID  Order_Date  Customer_Name    City       Product     Category  \
# 7    ORD110959  2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20   ORD105284  2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57   ORD127876  2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98   ORD106909  2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122  ORD100622  2023-01-21    Rahul Gupta  Jaipur     USB Cable  Electronics
#
#      Quantity  Unit_Price  Discount      Sales Payment_Mode Order_Status  \
# 7         2.0    87304.23      0.05  165878.04         Cash    Delivered
# 20        2.0    39138.52      0.05   74363.19         Cash    Cancelled
# 57        3.0    92085.50      0.20  221005.20       Wallet     Returned
# 98        2.0    34613.70      0.15   58843.29         Cash    Cancelled
# 122       5.0    52860.80      0.05  251088.80          UPI      Pending
#
#      Customer_Age  Rating  Delivery_Days
# ...

# %%
df["Rating"] = df["Rating"].fillna(df["Rating"].median())

# %%
df["Rating"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Payment_Mode"].isnull().sum()
# Out:
# np.int64(13)

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Order_ID"].duplicated()
# Out:
# 7        False
# 20       False
# 57       False
# 98       False
# 122      False
#          ...
# 30160    False
# 30166    False
# 30184    False
# 30221    False
# 30249    False
# Name: Order_ID, Length: 1374, dtype: bool

# %%
df=df.drop_duplicates(subset="Order_ID",keep="first")

# %%
print(df)
# Out:
#         Order_ID  Order_Date  Customer_Name    City       Product  \
# 7      ORD110959  2024-08-23    Simran Jain  Jaipur    Smartwatch
# 20     ORD105284  2023-09-23    Kavya Mehta  Jaipur     Hard Disk
# 57     ORD127876  2023-04-07    Aarav Verma  Jaipur        Camera
# 98     ORD106909  2024-03-17  Karan Agarwal  Jaipur  Gaming Chair
# 122    ORD100622  2023-01-21    Rahul Gupta  Jaipur     USB Cable
# ...          ...         ...            ...     ...           ...
# 30160  ORD113417  2023-07-18     Neha Gupta  Jaipur         Mouse
# 30166  ORD103943  2024-03-07   Anjali Verma  Jaipur  Gaming Chair
# 30184  ORD111016  2025-03-05    Amit Sharma  Jaipur     USB Cable
# 30221  ORD106420  2023-09-14    Sneha Singh  Jaipur    Smartwatch
# 30249  ORD123654  2024-08-12    Rohan Gupta  Jaipur       Earbuds
#
#           Category  Quantity  Unit_Price  Discount      Sales Payment_Mode  \
# 7      Electronics       2.0    87304.23      0.05  165878.04         Cash
# ...

# %%
df.sort_values( "Delivery_Days",ascending=False).head(10)
# Out:
#         Order_ID  Order_Date  Customer_Name    City       Product  \
# 7657   ORD127802  2024-05-27   Simran Joshi  Jaipur    Smartwatch
# 16601  ORD109613  2025-10-15  Priya Agarwal  Jaipur  Gaming Chair
# 20969  ORD115682  2025-11-13     Mohit Khan  Jaipur         Mouse
# 11082  ORD123949  2025-03-29   Vikas Sharma  Jaipur    Power Bank
# 21226  ORD104067  2024-06-23   Priya Sharma  Jaipur  Gaming Chair
# 10722  ORD101905  2023-08-12    Aarav Joshi  Jaipur    Headphones
# 10482  ORD113955  2024-01-06      Neha Khan  Jaipur       Earbuds
# 10046  ORD100711  2023-05-04    Aditi Gupta  Jaipur       Speaker
# 21945  ORD108963  2025-04-10    Neha Sharma  Jaipur        Webcam
# 21997  ORD103908  2024-08-24   Kavya Sharma  Jaipur        Webcam
#
#           Category  Quantity  Unit_Price  Discount      Sales Payment_Mode  \
# 7657     Computers       1.0    39926.90      0.25   29945.18          UPI
# 16601       Gaming       7.0    66034.03      0.30  323566.75  Net Banking
# ...

# %%
print(df['Order_Date'].head())
# Out:
# 7      2024-08-23
# 20     2023-09-23
# 57     2023-04-07
# 98     2024-03-17
# 122    2023-01-21
# Name: Order_Date, dtype: object

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors = 'coerce')

# %%
print(df)
# Out:
#         Order_ID Order_Date  Customer_Name    City       Product     Category  \
# 7      ORD110959 2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20     ORD105284 2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57     ORD127876 2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98     ORD106909 2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122    ORD100622 2023-01-21    Rahul Gupta  Jaipur     USB Cable  Electronics
# ...          ...        ...            ...     ...           ...          ...
# 30160  ORD113417 2023-07-18     Neha Gupta  Jaipur         Mouse       Gaming
# 30166  ORD103943 2024-03-07   Anjali Verma  Jaipur  Gaming Chair  Accessories
# 30184  ORD111016 2025-03-05    Amit Sharma  Jaipur     USB Cable    Computers
# 30221  ORD106420 2023-09-14    Sneha Singh  Jaipur    Smartwatch  Electronics
# 30249  ORD123654 2024-08-12    Rohan Gupta  Jaipur       Earbuds    Computers
#
# ...

# %%
print(df['Order_Date'].dtype)
# Out:
# datetime64[ns]

# %%
df['Order_Year'] = df['Order_Date'].dt.year

# %%
print(df)
# Out:
#         Order_ID Order_Date  Customer_Name    City       Product     Category  \
# 7      ORD110959 2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20     ORD105284 2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57     ORD127876 2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98     ORD106909 2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122    ORD100622 2023-01-21    Rahul Gupta  Jaipur     USB Cable  Electronics
# ...          ...        ...            ...     ...           ...          ...
# 30160  ORD113417 2023-07-18     Neha Gupta  Jaipur         Mouse       Gaming
# 30166  ORD103943 2024-03-07   Anjali Verma  Jaipur  Gaming Chair  Accessories
# 30184  ORD111016 2025-03-05    Amit Sharma  Jaipur     USB Cable    Computers
# 30221  ORD106420 2023-09-14    Sneha Singh  Jaipur    Smartwatch  Electronics
# 30249  ORD123654 2024-08-12    Rohan Gupta  Jaipur       Earbuds    Computers
#
# ...

# %%
df['Order_Month'] = df['Order_Date'].dt.month

# %%
print(df)
# Out:
#         Order_ID Order_Date  Customer_Name    City       Product     Category  \
# 7      ORD110959 2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20     ORD105284 2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57     ORD127876 2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98     ORD106909 2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122    ORD100622 2023-01-21    Rahul Gupta  Jaipur     USB Cable  Electronics
# ...          ...        ...            ...     ...           ...          ...
# 30160  ORD113417 2023-07-18     Neha Gupta  Jaipur         Mouse       Gaming
# 30166  ORD103943 2024-03-07   Anjali Verma  Jaipur  Gaming Chair  Accessories
# 30184  ORD111016 2025-03-05    Amit Sharma  Jaipur     USB Cable    Computers
# 30221  ORD106420 2023-09-14    Sneha Singh  Jaipur    Smartwatch  Electronics
# 30249  ORD123654 2024-08-12    Rohan Gupta  Jaipur       Earbuds    Computers
#
# ...

# %%
df.groupby('Order_Year')['Sales'].sum()
# Out:
# Order_Year
# 2023.0    96507251.36
# 2024.0    91595749.67
# 2025.0    91662187.36
# Name: Sales, dtype: float64

# %%
df['City'] = df['City'].str.strip().str.title()

# %%
print(df)
# Out:
#         Order_ID Order_Date  Customer_Name    City       Product     Category  \
# 7      ORD110959 2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20     ORD105284 2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57     ORD127876 2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98     ORD106909 2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122    ORD100622 2023-01-21    Rahul Gupta  Jaipur     USB Cable  Electronics
# ...          ...        ...            ...     ...           ...          ...
# 30160  ORD113417 2023-07-18     Neha Gupta  Jaipur         Mouse       Gaming
# 30166  ORD103943 2024-03-07   Anjali Verma  Jaipur  Gaming Chair  Accessories
# 30184  ORD111016 2025-03-05    Amit Sharma  Jaipur     USB Cable    Computers
# 30221  ORD106420 2023-09-14    Sneha Singh  Jaipur    Smartwatch  Electronics
# 30249  ORD123654 2024-08-12    Rohan Gupta  Jaipur       Earbuds    Computers
#
# ...

# %%
df['Product'] = df['Product'].str.strip().str.title()

# %%
print(df)
# Out:
#         Order_ID Order_Date  Customer_Name    City       Product     Category  \
# 7      ORD110959 2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20     ORD105284 2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57     ORD127876 2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98     ORD106909 2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122    ORD100622 2023-01-21    Rahul Gupta  Jaipur     Usb Cable  Electronics
# ...          ...        ...            ...     ...           ...          ...
# 30160  ORD113417 2023-07-18     Neha Gupta  Jaipur         Mouse       Gaming
# 30166  ORD103943 2024-03-07   Anjali Verma  Jaipur  Gaming Chair  Accessories
# 30184  ORD111016 2025-03-05    Amit Sharma  Jaipur     Usb Cable    Computers
# 30221  ORD106420 2023-09-14    Sneha Singh  Jaipur    Smartwatch  Electronics
# 30249  ORD123654 2024-08-12    Rohan Gupta  Jaipur       Earbuds    Computers
#
# ...

# %%
df['Payment_Mode'] = df['Payment_Mode'].str.strip().str.title()

# %%
print(df)
# Out:
#         Order_ID Order_Date  Customer_Name    City       Product     Category  \
# 7      ORD110959 2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20     ORD105284 2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57     ORD127876 2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98     ORD106909 2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122    ORD100622 2023-01-21    Rahul Gupta  Jaipur     Usb Cable  Electronics
# ...          ...        ...            ...     ...           ...          ...
# 30160  ORD113417 2023-07-18     Neha Gupta  Jaipur         Mouse       Gaming
# 30166  ORD103943 2024-03-07   Anjali Verma  Jaipur  Gaming Chair  Accessories
# 30184  ORD111016 2025-03-05    Amit Sharma  Jaipur     Usb Cable    Computers
# 30221  ORD106420 2023-09-14    Sneha Singh  Jaipur    Smartwatch  Electronics
# 30249  ORD123654 2024-08-12    Rohan Gupta  Jaipur       Earbuds    Computers
#
# ...

# %%
df['Order_Status'] = df['Order_Status'].str.strip().str.title()

# %%
print(df)
# Out:
#         Order_ID Order_Date  Customer_Name    City       Product     Category  \
# 7      ORD110959 2024-08-23    Simran Jain  Jaipur    Smartwatch  Electronics
# 20     ORD105284 2023-09-23    Kavya Mehta  Jaipur     Hard Disk  Accessories
# 57     ORD127876 2023-04-07    Aarav Verma  Jaipur        Camera    Computers
# 98     ORD106909 2024-03-17  Karan Agarwal  Jaipur  Gaming Chair  Electronics
# 122    ORD100622 2023-01-21    Rahul Gupta  Jaipur     Usb Cable  Electronics
# ...          ...        ...            ...     ...           ...          ...
# 30160  ORD113417 2023-07-18     Neha Gupta  Jaipur         Mouse       Gaming
# 30166  ORD103943 2024-03-07   Anjali Verma  Jaipur  Gaming Chair  Accessories
# 30184  ORD111016 2025-03-05    Amit Sharma  Jaipur     Usb Cable    Computers
# 30221  ORD106420 2023-09-14    Sneha Singh  Jaipur    Smartwatch  Electronics
# 30249  ORD123654 2024-08-12    Rohan Gupta  Jaipur       Earbuds    Computers
#
# ...
